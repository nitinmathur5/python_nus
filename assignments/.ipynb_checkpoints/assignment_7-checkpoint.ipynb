# %%
'''
inputdata = """
In probability theory and statistics, Bayes’ theorem (alternatively Bayes’ law or Bayes' rule) describes the probability of an event, 
based on prior knowledge of conditions that might be related to the event. 
For example, if cancer is related to age, then, using Bayes’ theorem, a person’s age can be used to more accurately assess the probability 
that they have cancer, compared to the assessment of the probability of cancer made without knowledge of the person's age.
One of the many applications of Bayes' theorem is Bayesian inference, a particular approach to statistical inference. 
When applied, the probabilities involved in Bayes' theorem may have different probability interpretations. 
With the Bayesian probability interpretation the theorem expresses how a subjective degree of belief should rationally change to account
for availability of related evidence. Bayesian inference is fundamental to Bayesian statistics.
Bayes’ theorem is named after Reverend Thomas Bayes (/beɪz/; 1701–1761), who first provided an equation that allows new evidence to update beliefs in his An Essay towards solving a Problem in the Doctrine of Chances (1763). It was further developed by Pierre-Simon Laplace, who first published the modern formulation in his 1812 "Théorie analytique des probabilités". Sir Harold Jeffreys put Bayes’ algorithm and Laplace's formulation on an axiomatic basis. Jeffreys wrote that Bayes' theorem "is to the theory of probability what the Pythagorean theorem is to geometry".[1]
"""

print(inputdata)
count_occurances_of_this_word("theorem")

# 
# theorem = 8
# USE dictornay to store this data,

#OPTIONAL

#You should print the words with its occurance
# In = 20
# probabality = 

# CASE INSENSITVE

# also, write it into CSV
# Word_name, count
# In, 10
# theorem, 8
'''

# %%
#inputdata = "In probability theory and statistics, Bayes’ theorem (alternatively Bayes’ law or Bayes' rule) describes the probability of an event, based on prior knowledge of conditions that might be related to the event. For example, if cancer is related to age, then, using Bayes’ theorem, a person’s age can be used to more accurately assess the probability that they have cancer, compared to the assessment of the probability of cancer made without knowledge of the person's age. One of the many applications of Bayes' theorem is Bayesian inference, a particular approach to statistical inference. When applied, the probabilities involved in Bayes' theorem may have different probability interpretations. With the Bayesian probability interpretation the theorem expresses how a subjective degree of belief should rationally change to account for availability of related evidence. Bayesian inference is fundamental to Bayesian statistics. Bayes’ theorem is named after Reverend Thomas Bayes (/be?z/; 1701–1761), who first provided an equation that allows new evidence to update beliefs in his An Essay towards solving a Problem in the Doctrine of Chances (1763). It was further developed by Pierre-Simon Laplace, who first published the modern formulation in his 1812 \"Théorie analytique des probabilités\". Sir Harold Jeffreys put Bayes’ algorithm and Laplace\'s formulation on an axiomatic basis. Jeffreys wrote that Bayes' theorem is to the theory of probability what the Pythagorean theorem is to geometry.[1]"
#print inputdata
myDict = {}

def add_words_to_dict(line):
    global myDict
    for word in line.split(" "):
        if myDict.has_key(word):
            myDict[word] +=1
        else:
            myDict[word] = 1

with open("inputdata.txt") as f:
    word = "theorem"
    word_count = 0
    lines = f.readlines()
    for line in lines:
        line = line.strip().lower()
        add_words_to_dict(line)

with open("output.csv", "a") as w:
    for k,v in sorted(myDict.items()):
        w.write(str(k) + str(",") + str(v) + "\n")
        print(str(k) + str(",") + str(v))
# Out:
# "is,1
# "th�orie,1
# (/be?z/;,1
# (1763).,1
# (alternatively,1
# ,,1
# 1701�1761),,1
# 1812,1
# a,4
# account,1
# accurately,1
# after,1
# age,1
# age,,1
# age.,1
# algorithm,1
# allows,1
# an,4
# analytique,1
# and,2
# applications,1
# applied,,1
# approach,1
# assess,1
# assessment,1
# availability,1
# axiomatic,1
# based,1
# basis.,1
# bayes,1
# bayes',4
# bayesian,4
# bayes�,5
# be,2
# belief,1
# beliefs,1
# by,1
# can,1
# cancer,2
# cancer,,1
# chances,1
# change,1
# compared,1
# conditions,1
# degree,1
# des,1
# describes,1
# developed,1
# different,1
# doctrine,1
# equation,1
# essay,1
# event,,1
# event.,1
# evidence,1
# evidence.,1
# example,,1
# expresses,1
# first,2
# for,2
# formulation,2
# fundamental,1
# further,1
# geometry".[1],1
# harold,1
# have,2
# his,2
# how,1
# if,1
# in,5
# inference,1
# inference,,1
# inference.,1
# interpretation,1
# interpretations.,1
# involved,1
# is,5
# it,1
# jeffreys,2
# knowledge,2
# laplace's,1
# laplace,,1
# law,1
# made,1
# many,1
# may,1
# might,1
# modern,1
# more,1
# named,1
# new,1
# of,11
# on,2
# one,1
# or,1
# particular,1
# person's,1
# person�s,1
# pierre-simon,1
# prior,1
# probabilities,1
# probability,7
# probabilit�s".,1
# problem,1
# provided,1
# published,1
# put,1
# pythagorean,1
# rationally,1
# related,3
# reverend,1
# rule),1
# should,1
# sir,1
# solving,1
# statistical,1
# statistics,,1
# statistics.,1
# subjective,1
# that,4
# the,14
# then,,1
# theorem,8
# theory,2
# they,1
# thomas,1
# to,10
# towards,1
# update,1
# used,1
# using,1
# was,1
# what,1
# when,1
# who,2
# with,1
# without,1
# wrote,1
