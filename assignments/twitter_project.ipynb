# %%
# !pip install twitter
# Out:
# Collecting twitter
#   Downloading twitter-1.18.0-py2.py3-none-any.whl (54kB)
# Installing collected packages: twitter
# Successfully installed twitter-1.18.0

# %%
# !pip install tweepy
# Out:
# Collecting tweepy
#   Downloading tweepy-3.5.0-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.7.3 in d:\anaconda2\lib\site-packages (from tweepy)
# Requirement already satisfied: requests>=2.4.3 in d:\anaconda2\lib\site-packages (from tweepy)
# Collecting requests-oauthlib>=0.4.1 (from tweepy)
#   Downloading requests_oauthlib-0.8.0-py2.py3-none-any.whl
# Collecting oauthlib>=0.6.2 (from requests-oauthlib>=0.4.1->tweepy)
#   Downloading oauthlib-2.0.6.tar.gz (127kB)
# Building wheels for collected packages: oauthlib
#   Running setup.py bdist_wheel for oauthlib: started
#   Running setup.py bdist_wheel for oauthlib: finished with status 'done'
#   Stored in directory: C:\Users\NMath7167444\AppData\Local\pip\Cache\wheels\e5\46\f7\bb2fde81726295a13a71e3c6396d362ab408921c6562d6efc0
# Successfully built oauthlib
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-2.0.6 requests-oauthlib-0.8.0 tweepy-3.5.0

# %%
from twitter import *
import requests
import json
import csv
from pprint import pprint

#-----------------------------------------------------------------------
# filename for saving the twitter data
#-----------------------------------------------------------------------

filename = "twitter_project.csv"

#-----------------------------------------------------------------------
# Create Twitter API credentials 
#-----------------------------------------------------------------------

config = {"consumer_key" : "ADbOq9myUWsmK5FmdrEdf11vF",
          "consumer_secret" : "VH7apE8RMU5QpdMAGK0RH1cWHy6GKLlAnFNWZfHA7rMWp1EwiQ",
          "access_key" : "1468729806-BBLS6GgiSPG1ucMo3FpqZoE2imASfd17kX3sWYc",
          "access_secret" : "vpepjZU08hTruTR1qI5pum6aQhjUkIX7b592KEvyfYW96"}

#-----------------------------------------------------------------------
# create twitter API object
#-----------------------------------------------------------------------
twitter = Twitter(auth = OAuth(config["access_key"], config["access_secret"], 
                               config["consumer_key"], config["consumer_secret"]))

    

def write_header_to_a_csv_file():
    with open(filename, "ab") as csvfile:
        csv_writer = csv.writer(csvfile)
        csv_writer.writerow(["sno","created_at","screen_name","tweet"])

def write_to_csv(sno,created_at, screen_name, tweet):
    with open(filename, "ab") as csvfile:
        csv_writer = csv.writer(csvfile)
        csv_writer.writerow([sno,created_at,screen_name,tweet]) 

#-----------------------------------------------------------------------
# perform a basic search 
# Twitter API docs:
# https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets.html
#-----------------------------------------------------------------------
maxTweets = 10000   # Some arbitrary large number
tweetsPerQry = 100  # this is the max the API permits
searchQuery = 'amd'  # this is what we're searching for




tweetCount = 0

data = []

write_header_to_a_csv_file()

while (tweetCount < maxTweets) :
    if (tweetCount == 0) :
        query  = twitter.search.tweets(q = searchQuery,lang="en",count=tweetsPerQry)
        #pprint (query)
        for result in query["statuses"]:
            #print "(%s) @%s %s" % (result["created_at"], result["user"]["screen_name"], result["text"])
            data = [result["created_at"], result["user"]["screen_name"], result["text"]]
            # this is to convert the unicode character in json format
            data = map(lambda x: x.encode('unicode-escape').decode('utf-8'),data) 
            #print(data)
            write_to_csv(tweetCount,data[0], data[1], data[2])
            tweetCount += 1
        pprint(tweetCount) 
    else :
        query  = twitter.search.tweets(q = searchQuery,lang="en",count=tweetsPerQry,max_id=max_id_str)
        #pprint (query)      
        for result in query["statuses"]:
            #print "(%s) @%s %s" % (result["created_at"], result["user"]["screen_name"], result["text"])
            data = [result["created_at"], result["user"]["screen_name"], result["text"]]
            data = map(lambda x: x.encode('unicode-escape').decode('utf-8'),data) 
            #print(data)
            write_to_csv(tweetCount,data[0], data[1], data[2])
            tweetCount += 1
        pprint(tweetCount)         
    try : 
        new_url = query["search_metadata"]["next_results"] 
        max_id_str =new_url.split("&")[0].split("=")[-1]
        pprint ((max_id_str))
        #pprint (data)       
    except KeyError: 
        print("No more tweets found")
        break
# Out:
# 100
# u'928207034927013887'
# 186
# No more tweets found

# %%
data2 = twitter.search.tweets(q = "amd",lang="en",count=50,max_id=927668049494269952) 
test = data2["search_metadata"]["next_results"]
#max_id_str =new_url.split("&")[0].split("=")[-1]
pprint (data2) 
pprint (new_url)
# Out:
# {u'search_metadata': {u'completed_in': 0.052,
#                       u'count': 50,
#                       u'max_id': 927668049494269952L,
#                       u'max_id_str': u'927668049494269952',
#                       u'next_results': u'?max_id=927666561309134849&q=amd&lang=en&count=50&include_entities=1',
#                       u'query': u'amd',
#                       u'refresh_url': u'?since_id=927668049494269952&q=amd&lang=en&include_entities=1',
#                       u'since_id': 0,
#                       u'since_id_str': u'0'},
#  u'statuses': [{u'contributors': None,
#                 u'coordinates': None,
#                 u'created_at': u'Mon Nov 06 22:44:21 +0000 2017',
#                 u'entities': {u'hashtags': [],
#                               u'symbols': [],
#                               u'urls': [{u'display_url': u'engt.co/2zgjCcN',
#                                          u'expanded_url': u'http://engt.co/2zgjCcN',
#                                          u'indices': [55, 78],
#                                          u'url': u'https://t.co/E1BAsyYvHK'}],
#                               u'user_mentions': [{u'id': 14372486,
#                                                   u'id_str': u'14372486',
#                                                   u'indices': [83, 92],
#                                                   u'name': u'Engadget',
#                                                   u'screen_name': u'engadget'}]},
#                 u'favorite_count': 0,
#                 u'favorited': False,
#                 u'geo': None,
#                 u'id': 927668000764973056L,
#                 u'id_str': u'927668000764973056',
#                 u'in_reply_to_screen_name': None,
#                 u'in_reply_to_status_id': None,
#                 u'in_reply_to_status_id_str': None,
#                 u'in_reply_to_user_id': None,
#                 u'in_reply_to_user_id_str': None,
#                 u'is_quote_status': False,
#                 u'lang': u'en',
#                 u'metadata': {u'iso_language_code': u'en',
#                               u'result_type': u'recent'},
#                 u'place': None,
#                 u'possibly_sensitive': False,
#                 u'retweet_count': 0,
#                 u'retweeted': False,
#                 u'source': u'<a href="http://www.linkedin.com/" rel="nofollow">LinkedIn</a>',
#                 u'text': u'Intel squeezed an AMD graphics chip and RAM onto a CPU https://t.co/E1BAsyYvHK via @engadget',
#                 u'truncated': False,
#                 u'user': {u'contributors_enabled': False,
#                           u'created_at': u'Sun Jun 22 09:38:05 +0000 2014',
#                           u'default_profile': False,
#                           u'default_profile_image': False,
#                           u'description': u'Seeking Program Manager or Hardware Design Engineer in Electronics MNCs (Remote Role OK).',
#                           u'entities': {u'description': {u'urls': []},
#                                         u'url': {u'urls': [{u'display_url': u'engineerlabs.weebly.com',
#                                                             u'expanded_url': u'http://engineerlabs.weebly.com',
#                                                             u'indices': [0,
#                                                                          22],
#                                                             u'url': u'http://t.co/8yTkybHalV'}]}},
#                           u'favourites_count': 63,
#                           u'follow_request_sent': False,
#                           u'followers_count': 180,
#                           u'following': False,
#                           u'friends_count': 116,
#                           u'geo_enabled': False,
#                           u'has_extended_profile': True,
#                           u'id': 2581941512L,
#                           u'id_str': u'2581941512',
#                           u'is_translation_enabled': False,
#                           u'is_translator': False,
#                           u'lang': u'en',
#                           u'listed_count': 22,
#                           u'location': u'Philippines',
#                           u'name': u'Ivan A.',
#                           u'notifications': False,
#                           u'profile_background_color': u'000000',
#                           u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#                           u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#                           u'profile_background_tile': False,
#                           u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/2581941512/1437626641',
#                           u'profile_image_url': u'http://pbs.twimg.com/profile_images/627950549665583104/jgU0DqeY_normal.png',
#                           u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/627950549665583104/jgU0DqeY_normal.png',
#                           u'profile_link_color': u'4A913C',
#                           u'profile_sidebar_border_color': u'000000',
#                           u'profile_sidebar_fill_color': u'000000',
#                           u'profile_text_color': u'000000',
#                           u'profile_use_background_image': False,
#                           u'protected': False,
#                           u'screen_name': u'EngineerLabs',
#                           u'statuses_count': 11817,
#                           u'time_zone': u'Hong Kong',
#                           u'translator_type': u'none',
#                           u'url': u'http://t.co/8yTkybHalV',
#                           u'utc_offset': 28800,
#                           u'verified': False}},
#                {u'contributors': None,
#                 u'coordinates': None,
#                 u'created_at': u'Mon Nov 06 22:44:15 +0000 2017',
#                 u'entities': {u'hashtags': [],
#                               u'media': [{u'display_url': u'pic.twitter.com/WSbrrZXuPy',
#                                           u'expanded_url': u'https://twitter.com/PCGamesN/status/927667914433552389/photo/1',
#                                           u'id': 927587556874702848L,
#                                           u'id_str': u'927587556874702848',
#                                           u'indices': [115, 138],
#                                           u'media_url': u'http://pbs.twimg.com/media/DN9z9-mW0AAWmry.jpg',
#                                           u'media_url_https': u'https://pbs.twimg.com/media/DN9z9-mW0AAWmry.jpg',
#                                           u'sizes': {u'large': {u'h': 332,
#                                                                 u'resize': u'fit',
#                                                                 u'w': 590},
#                                                      u'medium': {u'h': 332,
#                                                                  u'resize': u'fit',
#                                                                  u'w': 590},
#                                                      u'small': {u'h': 332,
#                                                                 u'resize': u'fit',
#                                                                 u'w': 590},
#                                                      u'thumb': {u'h': 150,
#                                                                 u'resize': u'crop',
#                                                                 u'w': 150}},
#                                           u'source_status_id': 927667914433552389L,
#                                           u'source_status_id_str': u'927667914433552389',
#                                           u'source_user_id': 285837868,
#                                           u'source_user_id_str': u'285837868',
#                                           u'type': u'photo',
#                                           u'url': u'https://t.co/WSbrrZXuPy'}],
#                               u'symbols': [],
#                               u'urls': [{u'display_url': u'pcgamesn.com/intel-amd-kaby\u2026',
#                                          u'expanded_url': u'https://www.pcgamesn.com/intel-amd-kaby-lake-g',
#                                          u'indices': [91, 114],
#                                          u'url': u'https://t.co/nNVwkal1jp'}],
#                               u'user_mentions': [{u'id': 285837868,
#                                                   u'id_str': u'285837868',
#                                                   u'indices': [3, 12],
#                                                   u'name': u'PCGamesN',
#                                                   u'screen_name': u'PCGamesN'}]},
#                 u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/WSbrrZXuPy',
#                                                    u'expanded_url': u'https://twitter.com/PCGamesN/status/927667914433552389/photo/1',
#                                                    u'id': 927587556874702848L,
#                                                    u'id_str': u'927587556874702848',
#                                                    u'indices': [115, 138],
#                                                    u'media_url': u'http://pbs.twimg.com/media/DN9z9-mW0AAWmry.jpg',
#                                                    u'media_url_https': u'https://pbs.twimg.com/media/DN9z9-mW0AAWmry.jpg',
#                                                    u'sizes': {u'large': {u'h': 332,
#                                                                          u'resize': u'fit',
#                                                                          u'w': 590},
#                                                               u'medium': {u'h': 332,
#                                                                           u'resize': u'fit',
#                                                                           u'w': 590},
#                                                               u'small': {u'h': 332,
#                                                                          u'resize': u'fit',
#                                                                          u'w': 590},
#                                                               u'thumb': {u'h': 150,
#                                                                          u'resize': u'crop',
#                                                                          u'w': 150}},
#                                                    u'source_status_id': 927667914433552389L,
#                                                    u'source_status_id_str': u'927667914433552389',
#                                                    u'source_user_id': 285837868,
#                                                    u'source_user_id_str': u'285837868',
#                                                    u'type': u'photo',
#                                                    u'url': u'https://t.co/WSbrrZXuPy'}]},
#                 u'favorite_count': 0,
#                 u'favorited': False,
#                 u'geo': None,
#                 u'id': 927667977222320129L,
#                 u'id_str': u'927667977222320129',
#                 u'in_reply_to_screen_name': None,
#                 u'in_reply_to_status_id': None,
#                 u'in_reply_to_status_id_str': None,
#                 u'in_reply_to_user_id': None,
#                 u'in_reply_to_user_id_str': None,
#                 u'is_quote_status': False,
#                 u'lang': u'en',
#                 u'metadata': {u'iso_language_code': u'en',
#                               u'result_type': u'recent'},
#                 u'place': None,
#                 u'possibly_sensitive': False,
#                 u'retweet_count': 2,
#                 u'retweeted': False,
#                 u'retweeted_status': {u'contributors': None,
#                                       u'coordinates': None,
#                                       u'created_at': u'Mon Nov 06 22:44:00 +0000 2017',
#                                       u'entities': {u'hashtags': [],
#                                                     u'media': [{u'display_url': u'pic.twitter.com/WSbrrZXuPy',
#                                                                 u'expanded_url': u'https://twitter.com/PCGamesN/status/927667914433552389/photo/1',
#                                                                 u'id': 927587556874702848L,
#                                                                 u'id_str': u'927587556874702848',
#                                                                 u'indices': [101,
#                                                                              124],
#                                                                 u'media_url': u'http://pbs.twimg.com/media/DN9z9-mW0AAWmry.jpg',
#                                                                 u'media_url_https': u'https://pbs.twimg.com/media/DN9z9-mW0AAWmry.jpg',
#                                                                 u'sizes': {u'large': {u'h': 332,
#                                                                                       u'resize': u'fit',
#                                                                                       u'w': 590},
#                                                                            u'medium': {u'h': 332,
#                                                                                        u'resize': u'fit',
#                                                                                        u'w': 590},
#                                                                            u'small': {u'h': 332,
#                                                                                       u'resize': u'fit',
#                                                                                       u'w': 590},
#                                                                            u'thumb': {u'h': 150,
#                                                                                       u'resize': u'crop',
#                                                                                       u'w': 150}},
#                                                                 u'type': u'photo',
#                                                                 u'url': u'https://t.co/WSbrrZXuPy'}],
#                                                     u'symbols': [],
#                                                     u'urls': [{u'display_url': u'pcgamesn.com/intel-amd-kaby\u2026',
#                                                                u'expanded_url': u'https://www.pcgamesn.com/intel-amd-kaby-lake-g',
#                                                                u'indices': [77,
#                                                                             100],
#                                                                u'url': u'https://t.co/nNVwkal1jp'}],
#                                                     u'user_mentions': []},
#                                       u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/WSbrrZXuPy',
#                                                                          u'expanded_url': u'https://twitter.com/PCGamesN/status/927667914433552389/photo/1',
#                                                                          u'id': 927587556874702848L,
#                                                                          u'id_str': u'927587556874702848',
#                                                                          u'indices': [101,
#                                                                                       124],
#                                                                          u'media_url': u'http://pbs.twimg.com/media/DN9z9-mW0AAWmry.jpg',
#                                                                          u'media_url_https': u'https://pbs.twimg.com/media/DN9z9-mW0AAWmry.jpg',
#                                                                          u'sizes': {u'large': {u'h': 332,
#                                                                                                u'resize': u'fit',
#                                                                                                u'w': 590},
#                                                                                     u'medium': {u'h': 332,
#                                                                                                 u'resize': u'fit',
#                                                                                                 u'w': 590},
#                                                                                     u'small': {u'h': 332,
#                                                                                                u'resize': u'fit',
#                                                                                                u'w': 590},
#                                                                                     u'thumb': {u'h': 150,
#                                                                                                u'resize': u'crop',
#                                                                                                u'w': 150}},
#                                                                          u'type': u'photo',
#                                                                          u'url': u'https://t.co/WSbrrZXuPy'}]},
#                                       u'favorite_count': 3,
#                                       u'favorited': False,
#                                       u'geo': None,
#                                       u'id': 927667914433552389L,
#                                       u'id_str': u'927667914433552389',
#                                       u'in_reply_to_screen_name': None,
#                                       u'in_reply_to_status_id': None,
#                                       u'in_reply_to_status_id_str': None,
#                                       u'in_reply_to_user_id': None,
#                                       u'in_reply_to_user_id_str': None,
#                                       u'is_quote_status': False,
#                                       u'lang': u'en',
#                                       u'metadata': {u'iso_language_code': u'en',
#                                                     u'result_type': u'recent'},
#                                       u'place': None,
#                                       u'possibly_sensitive': False,
#                                       u'retweet_count': 2,
#                                       u'retweeted': False,
#                                       u'source': u'<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#                                       u'text': u'Beware low-flying pigs: Intel and AMD are working together on a mobile chip.\nhttps://t.co/nNVwkal1jp https://t.co/WSbrrZXuPy',
#                                       u'truncated': False,
#                                       u'user': {u'contributors_enabled': False,
#                                                 u'created_at': u'Thu Apr 21 21:48:30 +0000 2011',
#                                                 u'default_profile': False,
#                                                 u'default_profile_image': False,
#                                                 u'description': u'News, opinion and original feature content regarding the biggest and best in PC gaming.',
#                                                 u'entities': {u'description': {u'urls': []},
#                                                               u'url': {u'urls': [{u'display_url': u'pcgamesn.com',
#                                                                                   u'expanded_url': u'https://www.pcgamesn.com',
#                                                                                   u'indices': [0,
#                                                                                                23],
#                                                                                   u'url': u'https://t.co/bcvSi3DM4w'}]}},
#                                                 u'favourites_count': 2207,
#                                                 u'follow_request_sent': False,
#                                                 u'followers_count': 86916,
#                                                 u'following': False,
#                                                 u'friends_count': 23,
#                                                 u'geo_enabled': True,
#                                                 u'has_extended_profile': True,
#                                                 u'id': 285837868,
#                                                 u'id_str': u'285837868',
#                                                 u'is_translation_enabled': True,
#                                                 u'is_translator': False,
#                                                 u'lang': u'en',
#                                                 u'listed_count': 482,
#                                                 u'location': u'The Internet',
#                                                 u'name': u'PCGamesN',
#                                                 u'notifications': False,
#                                                 u'profile_background_color': u'000000',
#                                                 u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme14/bg.gif',
#                                                 u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme14/bg.gif',
#                                                 u'profile_background_tile': False,
#                                                 u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/285837868/1494496410',
#                                                 u'profile_image_url': u'http://pbs.twimg.com/profile_images/875517223925952513/e0fTj4UY_normal.jpg',
#                                                 u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/875517223925952513/e0fTj4UY_normal.jpg',
#                                                 u'profile_link_color': u'FA743E',
#                                                 u'profile_sidebar_border_color': u'000000',
#                                                 u'profile_sidebar_fill_color': u'000000',
#                                                 u'profile_text_color': u'000000',
#                                                 u'profile_use_background_image': False,
#                                                 u'protected': False,
#                                                 u'screen_name': u'PCGamesN',
#                                                 u'statuses_count': 47280,
#                                                 u'time_zone': u'Dublin',
#                                                 u'translator_type': u'regular',
#                                                 u'url': u'https://t.co/bcvSi3DM4w',
#                                                 u'utc_offset': 0,
#                                                 u'verified': True}},
#                 u'source': u'<a href="http://mvilla.it/fenix" rel="nofollow">Fenix for Android</a>',
#                 u'text': u'RT @PCGamesN: Beware low-flying pigs: Intel and AMD are working together on a mobile chip.\nhttps://t.co/nNVwkal1jp https://t.co/WSbrrZXuPy',
#                 u'truncated': False,
#                 u'user': {u'contributors_enabled': False,
#                           u'created_at': u'Tue Apr 10 15:08:04 +0000 2007',
#                           u'default_profile': False,
#                           u'default_profile_image': False,
#                           u'description': u'\xbf? y aprendiz de todo, oficial de nada. Un humano m\xe1s y creo que estar\xe9 estudiando toda la vida. (INTP)',
#                           u'entities': {u'description': {u'urls': []},
#                                         u'url': {u'urls': [{u'display_url': u'about.me/JIFF',
#                                                             u'expanded_url': u'http://about.me/JIFF',
#                                                             u'indices': [0,
#                                                                          23],
#                                                             u'url': u'https://t.co/aMUZywRwpt'}]}},
#                           u'favourites_count': 33229,
#                           u'follow_request_sent': False,
#                           u'followers_count': 1598,
#                           u'following': False,
#                           u'friends_count': 1324,
#                           u'geo_enabled': True,
#                           u'has_extended_profile': True,
#                           u'id': 4041161,
#                           u'id_str': u'4041161',
#                           u'is_translation_enabled': False,
#                           u'is_translator': False,
#                           u'lang': u'en',
#                           u'listed_count': 192,
#                           u'location': u'M\xe9xico',
#                           u'name': u'Jorge I. Figueroa',
#                           u'notifications': False,
#                           u'profile_background_color': u'1A1B1F',
#                           u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/433832383050022912/qkjcCo3f.jpeg',
#                           u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/433832383050022912/qkjcCo3f.jpeg',
#                           u'profile_background_tile': True,
#                           u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/4041161/1503723187',
#                           u'profile_image_url': u'http://pbs.twimg.com/profile_images/918225557573181440/35HznXmT_normal.jpg',
#                           u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/918225557573181440/35HznXmT_normal.jpg',
#                           u'profile_link_color': u'E81C4F',
#                           u'profile_sidebar_border_color': u'FFFFFF',
#                           u'profile_sidebar_fill_color': u'252429',
#                           u'profile_text_color': u'666666',
#                           u'profile_use_background_image': True,
#                           u'protected': False,
#                           u'screen_name': u'JIFF01',
#                           u'statuses_count': 193148,
#                           u'time_zone': u'Mexico City',
#                           u'translator_type': u'none',
#                           u'url': u'https://t.co/aMUZywRwpt',
#                           u'utc_offset': -21600,
#                           u'verified': False}},
#                {u'contributors': None,
#                 u'coordinates': None,
#                 u'created_at': u'Mon Nov 06 22:44:12 +0000 2017',
#                 u'entities': {u'hashtags': [],
#                               u'symbols': [],
#                               u'urls': [{u'display_url': u'financefollow.com/2017/11/intel-\u2026',
#                                          u'expanded_url': u'http://financefollow.com/2017/11/intel-teams-up-with-amd-for-new-8th-generation-processors-with-amd-gpus/',
#                                          u'indices': [72, 95],
#                                          u'url': u'https://t.co/YOXJhFhPJE'}],
#                               u'user_mentions': []},
#                 u'favorite_count': 0,
#                 u'favorited': False,
#                 u'geo': None,
#                 u'id': 927667964094111745L,
#                 u'id_str': u'927667964094111745',
#                 u'in_reply_to_screen_name': None,
#                 u'in_reply_to_status_id': None,
#                 u'in_reply_to_status_id_str': None,
#                 u'in_reply_to_user_id': None,
#                 u'in_reply_to_user_id_str': None,
#                 u'is_quote_status': False,
#                 u'lang': u'en',
#                 u'metadata': {u'iso_language_code': u'en',
#                               u'result_type': u'recent'},
#                 u'place': None,
#                 u'possibly_sensitive': False,
#                 u'retweet_count': 0,
#                 u'retweeted': False,
#                 u'source': u'<a href="http://financefollow.com" rel="nofollow">Finance Follow</a>',
#                 u'text': u'Intel Teams Up With AMD for New 8th-Generation Processors With AMD GPUs https://t.co/YOXJhFhPJE Longtime rivals Intel and AMD are',
#                 u'truncated': False,
#                 u'user': {u'contributors_enabled': False,
#                           u'created_at': u'Fri May 04 12:27:53 +0000 2012',
#                           u'default_profile': False,
#                           u'default_profile_image': False,
#                           u'description': u'Everything about Finance to Follow http://t.co/8wdPNlbugr',
#                           u'entities': {u'description': {u'urls': [{u'display_url': u'followfinance.com',
#                                                                     u'expanded_url': u'http://followfinance.com',
#                                                                     u'indices': [35,
#                                                                                  57],
#                                                                     u'url': u'http://t.co/8wdPNlbugr'}]},
#                                         u'url': {u'urls': [{u'display_url': u'financefollow.com',
#                                                             u'expanded_url': u'http://financefollow.com',
#                                                             u'indices': [0,
#                                                                          22],
#                                                             u'url': u'http://t.co/Ygx6s2EvWs'}]}},
#                           u'favourites_count': 2,
#                           u'follow_request_sent': False,
#                           u'followers_count': 2392,
#                           u'following': False,
#                           u'friends_count': 1914,
#                           u'geo_enabled': True,
#                           u'has_extended_profile': False,
#                           u'id': 570789542,
#                           u'id_str': u'570789542',
#                           u'is_translation_enabled': False,
#                           u'is_translator': False,
#                           u'lang': u'en',
#                           u'listed_count': 817,
#                           u'location': u'The Netherlands',
#                           u'name': u'Finance Follow',
#                           u'notifications': False,
#                           u'profile_background_color': u'0099B9',
#                           u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/550871703/follow_finance_397662_twitbacks.jpg',
#                           u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/550871703/follow_finance_397662_twitbacks.jpg',
#                           u'profile_background_tile': False,
#                           u'profile_image_url': u'http://pbs.twimg.com/profile_images/2214795357/money_50_normal.png',
#                           u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/2214795357/money_50_normal.png',
#                           u'profile_link_color': u'0099B9',
#                           u'profile_sidebar_border_color': u'5ED4DC',
#                           u'profile_sidebar_fill_color': u'95E8EC',
#                           u'profile_text_color': u'3C3940',
#                           u'profile_use_background_image': True,
#                           u'protected': False,
#                           u'screen_name': u'Follow_Finance',
#                           u'statuses_count': 414311,
#                           u'time_zone': u'Amsterdam',
#                           u'translator_type': u'none',
#                           u'url': u'http://t.co/Ygx6s2EvWs',
#                           u'utc_offset': 3600,
#                           u'verified': False}},
#                {u'contributors': None,
#                 u'coordinates': None,
#                 u'created_at': u'Mon Nov 06 22:44:06 +0000 2017',
#                 u'entities': {u'hashtags': [],
#                               u'symbols': [{u'indices': [70, 75],
#                                             u'text': u'AVGO'},
#                                            {u'indices': [76, 81],
#                                             u'text': u'QCOM'},
#                                            {u'indices': [82, 87],
#                                             u'text': u'INTC'},
#                                            {u'indices': [88, 92],
#                                             u'text': u'AMD'},
#                                            {u'indices': [97, 102],
#                                             u'text': u'NVDA'}],
#                               u'urls': [],
#                               u'user_mentions': [{u'id': 16732770,
#                                                   u'id_str': u'16732770',
#                                                   u'indices': [3, 17],
#                                                   u'name': u"CNBC's Fast Money",
#                                                   u'screen_name': u'CNBCFastMoney'}]},
#                 u'favorite_count': 0,
#                 u'favorited': False,
#                 u'geo': None,
#                 u'id': 927667937099636736L,
#                 u'id_str': u'927667937099636736',
#                 u'in_reply_to_screen_name': None,
#                 u'in_reply_to_status_id': None,
#                 u'in_reply_to_status_id_str': None,
#                 u'in_reply_to_user_id': None,
#                 u'in_reply_to_user_id_str': None,
#                 u'is_quote_status': False,
#                 u'lang': u'en',
#                 u'metadata': {u'iso_language_code': u'en',
#                               u'result_type': u'recent'},
#                 u'place': None,
#                 u'retweet_count': 24,
#                 u'retweeted': False,
#                 u'retweeted_status': {u'contributors': None,
#                                       u'coordinates': None,
#                                       u'created_at': u'Mon Nov 06 22:37:25 +0000 2017',
#                                       u'entities': {u'hashtags': [],
#                                                     u'media': [{u'display_url': u'pic.twitter.com/i6wlk3kxSa',
#                                                                 u'expanded_url': u'https://twitter.com/CNBCFastMoney/status/927666255007567875/photo/1',
#                                                                 u'id': 927666238398050311L,
#                                                                 u'id_str': u'927666238398050311',
#                                                                 u'indices': [117,
#                                                                              140],
#                                                                 u'media_url': u'http://pbs.twimg.com/media/DN-7h2HWsAc0-q2.jpg',
#                                                                 u'media_url_https': u'https://pbs.twimg.com/media/DN-7h2HWsAc0-q2.jpg',
#                                                                 u'sizes': {u'large': {u'h': 288,
#                                                                                       u'resize': u'fit',
#                                                                                       u'w': 1024},
#                                                                            u'medium': {u'h': 288,
#                                                                                        u'resize': u'fit',
#                                                                                        u'w': 1024},
#                                                                            u'small': {u'h': 191,
#                                                                                       u'resize': u'fit',
#                                                                                       u'w': 680},
#                                                                            u'thumb': {u'h': 150,
#                                                                                       u'resize': u'crop',
#                                                                                       u'w': 150}},
#                                                                 u'type': u'photo',
#                                                                 u'url': u'https://t.co/i6wlk3kxSa'}],
#                                                     u'symbols': [{u'indices': [51,
#                                                                                56],
#                                                                   u'text': u'AVGO'},
#                                                                  {u'indices': [57,
#                                                                                62],
#                                                                   u'text': u'QCOM'},
#                                                                  {u'indices': [63,
#                                                                                68],
#                                                                   u'text': u'INTC'},
#                                                                  {u'indices': [69,
#                                                                                73],
#                                                                   u'text': u'AMD'},
#                                                                  {u'indices': [78,
#                                                                                83],
#                                                                   u'text': u'NVDA'}],
#                                                     u'urls': [],
#                                                     u'user_mentions': []},
#                                       u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/i6wlk3kxSa',
#                                                                          u'expanded_url': u'https://twitter.com/CNBCFastMoney/status/927666255007567875/photo/1',
#                                                                          u'id': 927666238398050311L,
#                                                                          u'id_str': u'927666238398050311',
#                                                                          u'indices': [117,
#                                                                                       140],
#                                                                          u'media_url': u'http://pbs.twimg.com/media/DN-7h2HWsAc0-q2.jpg',
#                                                                          u'media_url_https': u'https://pbs.twimg.com/media/DN-7h2HWsAc0-q2.jpg',
#                                                                          u'sizes': {u'large': {u'h': 288,
#                                                                                                u'resize': u'fit',
#                                                                                                u'w': 1024},
#                                                                                     u'medium': {u'h': 288,
#                                                                                                 u'resize': u'fit',
#                                                                                                 u'w': 1024},
#                                                                                     u'small': {u'h': 191,
#                                                                                                u'resize': u'fit',
#                                                                                                u'w': 680},
#                                                                                     u'thumb': {u'h': 150,
#                                                                                                u'resize': u'crop',
#                                                                                                u'w': 150}},
#                                                                          u'type': u'photo',
#                                                                          u'url': u'https://t.co/i6wlk3kxSa'}]},
#                                       u'favorite_count': 25,
#                                       u'favorited': False,
#                                       u'geo': None,
#                                       u'id': 927666255007567875L,
#                                       u'id_str': u'927666255007567875',
#                                       u'in_reply_to_screen_name': None,
#                                       u'in_reply_to_status_id': None,
#                                       u'in_reply_to_status_id_str': None,
#                                       u'in_reply_to_user_id': None,
#                                       u'in_reply_to_user_id_str': None,
#                                       u'is_quote_status': False,
#                                       u'lang': u'en',
#                                       u'metadata': {u'iso_language_code': u'en',
#                                                     u'result_type': u'recent'},
#                                       u'place': None,
#                                       u'possibly_sensitive': False,
#                                       u'retweet_count': 24,
#                                       u'retweeted': False,
#                                       u'source': u'<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#                                       u'text': u"Chip stocks soaring to new highs today. Here's how $AVGO $QCOM $INTC $AMD and $NVDA have performed in the last year. https://t.co/i6wlk3kxSa",
#                                       u'truncated': False,
#                                       u'user': {u'contributors_enabled': False,
#                                                 u'created_at': u'Tue Oct 14 03:16:30 +0000 2008',
#                                                 u'default_profile': False,
#                                                 u'default_profile_image': False,
#                                                 u'description': u"Fast Money with @MelissaLeeCNBC airs weeknights at 5P ET, only on @CNBC. America's post-market show.",
#                                                 u'entities': {u'description': {u'urls': []},
#                                                               u'url': {u'urls': [{u'display_url': u'fastmoney.cnbc.com',
#                                                                                   u'expanded_url': u'http://fastmoney.cnbc.com',
#                                                                                   u'indices': [0,
#                                                                                                23],
#                                                                                   u'url': u'https://t.co/g476qiApSd'}]}},
#                                                 u'favourites_count': 1982,
#                                                 u'follow_request_sent': False,
#                                                 u'followers_count': 191756,
#                                                 u'following': True,
#                                                 u'friends_count': 1288,
#                                                 u'geo_enabled': False,
#                                                 u'has_extended_profile': False,
#                                                 u'id': 16732770,
#                                                 u'id_str': u'16732770',
#                                                 u'is_translation_enabled': False,
#                                                 u'is_translator': False,
#                                                 u'lang': u'en',
#                                                 u'listed_count': 2986,
#                                                 u'location': u'NASDAQ',
#                                                 u'name': u"CNBC's Fast Money",
#                                                 u'notifications': False,
#                                                 u'profile_background_color': u'0D181F',
#                                                 u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/378800000008568647/b8238ba4b7b9547254d954a2876d44d3.png',
#                                                 u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/378800000008568647/b8238ba4b7b9547254d954a2876d44d3.png',
#                                                 u'profile_background_tile': False,
#                                                 u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/16732770/1481922975',
#                                                 u'profile_image_url': u'http://pbs.twimg.com/profile_images/819679248956977153/GTAbjy_O_normal.jpg',
#                                                 u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/819679248956977153/GTAbjy_O_normal.jpg',
#                                                 u'profile_link_color': u'727722',
#                                                 u'profile_sidebar_border_color': u'FFFFFF',
#                                                 u'profile_sidebar_fill_color': u'BEBFBA',
#                                                 u'profile_text_color': u'333333',
#                                                 u'profile_use_background_image': True,
#                                                 u'protected': False,
#                                                 u'screen_name': u'CNBCFastMoney',
#                                                 u'statuses_count': 40313,
#                                                 u'time_zone': u'Eastern Time (US & Canada)',
#                                                 u'translator_type': u'none',
#                                                 u'url': u'https://t.co/g476qiApSd',
#                                                 u'utc_offset': -18000,
#                                                 u'verified': True}},
#                 u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#                 u'text': u"RT @CNBCFastMoney: Chip stocks soaring to new highs today. Here's how $AVGO $QCOM $INTC $AMD and $NVDA have performed in the last year. htt\u2026",
#                 u'truncated': False,
#                 u'user': {u'contributors_enabled': False,
#                           u'created_at': u'Wed Sep 20 14:25:26 +0000 2017',
#                           u'default_profile': False,
#                           u'default_profile_image': False,
#                           u'description': u'\U0001f4ca I like to talk stocks\U0001f4c8 Empowering the individual investor through the link below \U0001f4dd\U0001f4da',
#                           u'entities': {u'description': {u'urls': []},
#                                         u'url': {u'urls': [{u'display_url': u'sisumoney.com',
#                                                             u'expanded_url': u'http://www.sisumoney.com',
#                                                             u'indices': [0,
#                                                                          23],
#                                                             u'url': u'https://t.co/m1WpE03zs5'}]}},
#                           u'favourites_count': 348,
#                           u'follow_request_sent': False,
#                           u'followers_count': 71,
# ...
#                                                                                                 u'resize': u'fit',
#                                                                                                 u'w': 1024},
#                                                                                     u'small': {u'h': 191,
#                                                                                                u'resize': u'fit',
#                                                                                                u'w': 680},
#                                                                                     u'thumb': {u'h': 150,
#                                                                                                u'resize': u'crop',
#                                                                                                u'w': 150}},
#                                                                          u'type': u'photo',
#                                                                          u'url': u'https://t.co/i6wlk3kxSa'}]},
#                                       u'favorite_count': 25,
#                                       u'favorited': False,
#                                       u'geo': None,
#                                       u'id': 927666255007567875L,
#                                       u'id_str': u'927666255007567875',
#                                       u'in_reply_to_screen_name': None,
#                                       u'in_reply_to_status_id': None,
#                                       u'in_reply_to_status_id_str': None,
#                                       u'in_reply_to_user_id': None,
#                                       u'in_reply_to_user_id_str': None,
#                                       u'is_quote_status': False,
#                                       u'lang': u'en',
#                                       u'metadata': {u'iso_language_code': u'en',
#                                                     u'result_type': u'recent'},
#                                       u'place': None,
#                                       u'possibly_sensitive': False,
#                                       u'retweet_count': 24,
#                                       u'retweeted': False,
#                                       u'source': u'<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#                                       u'text': u"Chip stocks soaring to new highs today. Here's how $AVGO $QCOM $INTC $AMD and $NVDA have performed in the last year. https://t.co/i6wlk3kxSa",
#                                       u'truncated': False,
#                                       u'user': {u'contributors_enabled': False,
#                                                 u'created_at': u'Tue Oct 14 03:16:30 +0000 2008',
#                                                 u'default_profile': False,
#                                                 u'default_profile_image': False,
#                                                 u'description': u"Fast Money with @MelissaLeeCNBC airs weeknights at 5P ET, only on @CNBC. America's post-market show.",
#                                                 u'entities': {u'description': {u'urls': []},
#                                                               u'url': {u'urls': [{u'display_url': u'fastmoney.cnbc.com',
#                                                                                   u'expanded_url': u'http://fastmoney.cnbc.com',
#                                                                                   u'indices': [0,
#                                                                                                23],
#                                                                                   u'url': u'https://t.co/g476qiApSd'}]}},
#                                                 u'favourites_count': 1982,
#                                                 u'follow_request_sent': False,
#                                                 u'followers_count': 191756,
#                                                 u'following': True,
#                                                 u'friends_count': 1288,
#                                                 u'geo_enabled': False,
#                                                 u'has_extended_profile': False,
#                                                 u'id': 16732770,
#                                                 u'id_str': u'16732770',
#                                                 u'is_translation_enabled': False,
#                                                 u'is_translator': False,
#                                                 u'lang': u'en',
#                                                 u'listed_count': 2986,
#                                                 u'location': u'NASDAQ',
#                                                 u'name': u"CNBC's Fast Money",
#                                                 u'notifications': False,
#                                                 u'profile_background_color': u'0D181F',
#                                                 u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/378800000008568647/b8238ba4b7b9547254d954a2876d44d3.png',
#                                                 u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/378800000008568647/b8238ba4b7b9547254d954a2876d44d3.png',
#                                                 u'profile_background_tile': False,
#                                                 u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/16732770/1481922975',
#                                                 u'profile_image_url': u'http://pbs.twimg.com/profile_images/819679248956977153/GTAbjy_O_normal.jpg',
#                                                 u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/819679248956977153/GTAbjy_O_normal.jpg',
#                                                 u'profile_link_color': u'727722',
#                                                 u'profile_sidebar_border_color': u'FFFFFF',
#                                                 u'profile_sidebar_fill_color': u'BEBFBA',
#                                                 u'profile_text_color': u'333333',
#                                                 u'profile_use_background_image': True,
#                                                 u'protected': False,
#                                                 u'screen_name': u'CNBCFastMoney',
#                                                 u'statuses_count': 40313,
#                                                 u'time_zone': u'Eastern Time (US & Canada)',
#                                                 u'translator_type': u'none',
#                                                 u'url': u'https://t.co/g476qiApSd',
#                                                 u'utc_offset': -18000,
#                                                 u'verified': True}},
#                 u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#                 u'text': u"RT @CNBCFastMoney: Chip stocks soaring to new highs today. Here's how $AVGO $QCOM $INTC $AMD and $NVDA have performed in the last year. htt\u2026",
#                 u'truncated': False,
#                 u'user': {u'contributors_enabled': False,
#                           u'created_at': u'Wed Jan 21 15:00:36 +0000 2009',
#                           u'default_profile': False,
#                           u'default_profile_image': False,
#                           u'description': u'Owner of full service web agency | Any Screen Size  & DAA Manager at ICONOMI | CARUS-AR - https://t.co/QVQrhgzSDh & https://t.co/xUNGZDsrtT',
#                           u'entities': {u'description': {u'urls': [{u'display_url': u'anyscreensize.com',
#                                                                     u'expanded_url': u'https://anyscreensize.com',
#                                                                     u'indices': [90,
#                                                                                  113],
#                                                                     u'url': u'https://t.co/QVQrhgzSDh'},
#                                                                    {u'display_url': u'carus-ar.com',
#                                                                     u'expanded_url': u'https://carus-ar.com',
#                                                                     u'indices': [116,
#                                                                                  139],
#                                                                     u'url': u'https://t.co/xUNGZDsrtT'}]},
#                                         u'url': {u'urls': [{u'display_url': u'anyscreensize.com',
#                                                             u'expanded_url': u'https://anyscreensize.com',
#                                                             u'indices': [0,
#                                                                          23],
#                                                             u'url': u'https://t.co/QVQrhgzSDh'}]}},
#                           u'favourites_count': 2489,
#                           u'follow_request_sent': False,
#                           u'followers_count': 2002,
#                           u'following': False,
#                           u'friends_count': 2349,
#                           u'geo_enabled': True,
#                           u'has_extended_profile': True,
#                           u'id': 19290355,
#                           u'id_str': u'19290355',
#                           u'is_translation_enabled': False,
#                           u'is_translator': False,
#                           u'lang': u'en',
#                           u'listed_count': 199,
#                           u'location': u'Den Bosch',
#                           u'name': u'Menno Pietersen',
#                           u'notifications': False,
#                           u'profile_background_color': u'FFFFFF',
#                           u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/75659201/Twitter_bg.jpg',
#                           u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/75659201/Twitter_bg.jpg',
#                           u'profile_background_tile': False,
#                           u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/19290355/1429386789',
#                           u'profile_image_url': u'http://pbs.twimg.com/profile_images/2705227415/d18c941da75cffe7c10d9f7ce6e016af_normal.png',
#                           u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/2705227415/d18c941da75cffe7c10d9f7ce6e016af_normal.png',
#                           u'profile_link_color': u'FA743E',
#                           u'profile_sidebar_border_color': u'FFFFFF',
#                           u'profile_sidebar_fill_color': u'EBEBEB',
#                           u'profile_text_color': u'666666',
#                           u'profile_use_background_image': True,
#                           u'protected': False,
#                           u'screen_name': u'MennoPP',
#                           u'statuses_count': 8306,
#                           u'time_zone': u'Amsterdam',
#                           u'translator_type': u'none',
#                           u'url': u'https://t.co/QVQrhgzSDh',
#                           u'utc_offset': 3600,
#                           u'verified': False}},
#                {u'contributors': None,
#                 u'coordinates': None,
#                 u'created_at': u'Mon Nov 06 22:38:38 +0000 2017',
#                 u'entities': {u'hashtags': [{u'indices': [81, 104],
#                                              u'text': u'loveandhiphophollywood'},
#                                             {u'indices': [106, 111],
#                                              u'text': u'lhhp'}],
#                               u'symbols': [],
#                               u'urls': [],
#                               u'user_mentions': []},
#                 u'favorite_count': 0,
#                 u'favorited': False,
#                 u'geo': None,
#                 u'id': 927666561309134850L,
#                 u'id_str': u'927666561309134850',
#                 u'in_reply_to_screen_name': None,
#                 u'in_reply_to_status_id': None,
#                 u'in_reply_to_status_id_str': None,
#                 u'in_reply_to_user_id': None,
#                 u'in_reply_to_user_id_str': None,
#                 u'is_quote_status': False,
#                 u'lang': u'en',
#                 u'metadata': {u'iso_language_code': u'en',
#                               u'result_type': u'recent'},
#                 u'place': None,
#                 u'retweet_count': 0,
#                 u'retweeted': False,
#                 u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#                 u'text': u'About to cook these oxtails its going down with brown rice amd veggies and watch #loveandhiphophollywood. #lhhp',
#                 u'truncated': False,
#                 u'user': {u'contributors_enabled': False,
#                           u'created_at': u'Thu Aug 17 08:58:46 +0000 2017',
#                           u'default_profile': True,
#                           u'default_profile_image': False,
#                           u'description': u"I LIVE BY MY 3 C's CALM \U0001f192COLLECTIVE!!!!\U0001f4af\U0001f601\U0001f61d\U0001f48b\U0001f498\U0001f48b\U0001f496\U0001f48b",
#                           u'entities': {u'description': {u'urls': []}},
#                           u'favourites_count': 1826,
#                           u'follow_request_sent': False,
#                           u'followers_count': 980,
#                           u'following': False,
#                           u'friends_count': 1134,
#                           u'geo_enabled': False,
#                           u'has_extended_profile': False,
#                           u'id': 898106818307780608L,
#                           u'id_str': u'898106818307780608',
#                           u'is_translation_enabled': False,
#                           u'is_translator': False,
#                           u'lang': u'en',
#                           u'listed_count': 0,
#                           u'location': u'United States',
#                           u'name': u'Zay',
#                           u'notifications': False,
#                           u'profile_background_color': u'F5F8FA',
#                           u'profile_background_image_url': None,
#                           u'profile_background_image_url_https': None,
#                           u'profile_background_tile': False,
#                           u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/898106818307780608/1504431335',
#                           u'profile_image_url': u'http://pbs.twimg.com/profile_images/927731431438249984/uaIG2xZ1_normal.jpg',
#                           u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/927731431438249984/uaIG2xZ1_normal.jpg',
#                           u'profile_link_color': u'1DA1F2',
#                           u'profile_sidebar_border_color': u'C0DEED',
#                           u'profile_sidebar_fill_color': u'DDEEF6',
#                           u'profile_text_color': u'333333',
#                           u'profile_use_background_image': True,
#                           u'protected': False,
#                           u'screen_name': u'zayrealbaby',
#                           u'statuses_count': 948,
#                           u'time_zone': None,
#                           u'translator_type': u'none',
#                           u'url': None,
#                           u'utc_offset': None,
#                           u'verified': False}}]}
# u'?max_id=927668049494269952&q=Micron&lang=en&count=100&include_entities=1'

# %% [markdown]
# data2 = twitter.search.tweets(q = "amd",lang="en",count=50,max_id=max_id_str)
# new_url = data2["search_metadata"]["next_results"]
# #max_id_str =new_url.split("&")[0].split("=")[-1]
#
# pprint (data2)
# pprint (new_url)
